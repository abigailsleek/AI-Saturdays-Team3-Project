# %% [markdown]
# <a href="https://colab.research.google.com/github/abigailsleek/AI-Saturdays-Team3-Project/blob/master/Team3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sbn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
DATA = pd.read_csv('/content/drive/My Drive/personal/NIGERIA_DEMOGRAPHICS_DATA - NIGERIA_DEMOGRAPHICS_DATA.csv')

# %%
DATA.head()
# Out:
#              Timestamp  ... Please fill your email if you want to be notified once this research is completed.
# 0  10/13/2019 17:45:01  ...                              ikeoluwa933@gmail.com
# 1  10/13/2019 18:13:59  ...                                                NaN
# 2  10/13/2019 20:11:39  ...                      olanrewaju1temitayo@gmail.com
# 3  10/13/2019 20:17:57  ...                          adewunmi.fatoki@gmail.com
# 4   10/14/2019 6:24:13  ...                               Johnnyark9@gmail.com
#
# [5 rows x 22 columns]

# %% [markdown]
# #* **Cleaning Data**
# Droping columns with NAN values

# %%
#dropping null values
DATA.dropna()
# Out:
#                Timestamp  ... Please fill your email if you want to be notified once this research is completed.
# 14   10/15/2019 11:13:37  ...                             dosuntoyinbo@gmail.com
# 17   10/15/2019 11:24:26  ...                       oluwabukunmi.aluko@gmail.com
# 18   10/15/2019 11:46:46  ...                               solomo.obs@gmail.com
# 20   10/15/2019 11:51:57  ...                                 feronz10@yahoo.com
# 21   10/15/2019 12:10:12  ...                                akinslamp@yahoo.com
# ..                   ...  ...                                                ...
# 294   11/4/2019 10:16:03  ...                     Ojoolawalejulius2016@gmail.com
# 296   11/5/2019 19:54:01  ...                        ibukunoluwa.sarah@gmail.com
# 299   11/10/2019 8:10:53  ...                               Omoologo08@gmail.com
# 301  11/14/2019 12:33:44  ...                                                 No
# ...

# %%
#DATA.drop(['Timestamp'], axis=1, inplace=False)

# %%
#trying to get the shape of the data to know the total number of entries
DATA.shape
# Out:
# (303, 22)

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 22 columns):
# Timestamp                                                                             303 non-null object
# Are you a Nigerian?                                                                   288 non-null object
# Gender                                                                                303 non-null object
# Age Group                                                                             303 non-null object
# Are you married?                                                                      303 non-null object
# Do you have kids?                                                                     303 non-null object
# Where do you live?                                                                    303 non-null object
# What part of your state do you live in?                                               303 non-null object
# ...

# %%
DATA.describe()
# Out:
#        How much do you think you earn from all other sources of income in a month  On an average, how much do you think you spend in a month?
# count                                       3.020000e+02                                                                3.030000e+02
# mean                                        6.627668e+07                                                                1.650782e+08
# std                                         8.124313e+08                                                                2.872421e+09
# min                                         0.000000e+00                                                                0.000000e+00
# 25%                                         5.500000e+01                                                                2.000000e+04
# 50%                                         1.500000e+04                                                                4.700000e+04
# ...

# %% [markdown]
# **Exploratory Data Analysis**
#
# Visualize this sgiven data to get insights.
#
# To be able to get certain traits and understand the mindset of an average Nigerian.

# %%
DATA['Occupation'].value_counts()
# Out:
# Software Engineering /Computer Design    50
# Student                                  48
# Engineering                              31
# Entrepreneur                             28
# Financial Services                       27
# No Job                                   25
# Student and Working                      23
# Others                                   18
# Business                                 16
# Consultant                               16
# Health                                   10
# I don’t know                              9
# Farmer                                    1
# Name: Occupation, dtype: int64

# %%
occupation=sbn.countplot(y="Occupation", data=DATA, saturation=0.5)

# %%
DATA['What is your largest form of expense'].value_counts()
# Out:
# Feeding                 102
# Transportation           82
# Rent                     63
# School Fees              23
# Airtime and Data         20
# Clothing and Jewelry      9
# Tax                       2
# Medical Bills             1
# Bribery                   1
# Name: What is your largest form of expense, dtype: int64

# %%
expense = sbn.countplot(y="What is your largest form of expense", data= DATA, saturation=0.5)

# %%
plt.plot(DATA['What is your largest form of expense'].value_counts(),data=DATA,scalex=True, scaley=True)
plt.show()

# %%
DATA['Age Group'].value_counts()
# Out:
# 18 – 25    181
# 26 – 35    104
# 36 – 45     13
# 46 – 55      4
# 56 – 65      1
# Name: Age Group, dtype: int64

# %%
plt.plot(DATA['Age Group'].value_counts(), color="green")
plt.title("graph showing the age ranges")
plt.show()

# %%
Ages = sbn.countplot(x="Age Group", data= DATA, saturation=0.9)

# %%
DATA['What are your other sources of income?'].value_counts()
# Out:
# None                                                     102
# Free Lancing                                              88
# Buying and Selling                                        34
# Formal Job                                                16
# Free Lancing, Buying and Selling                          14
# Contractor                                                12
# Betting (Bet Naija)                                       10
# Free Lancing, Betting (Bet Naija)                          7
# Free Lancing, Contractor                                   6
# Free Lancing, Formal Job                                   3
# Betting (Bet Naija), Buying and Selling                    3
# Free Lancing, Formal Job, Buying and Selling               2
# Free Lancing, Betting (Bet Naija), Contractor              1
# Free Lancing, Buying and Selling, Contractor               1
# Buying and Selling, Contractor                             1
# ...

# %%
Other = sbn.countplot(y='What are your other sources of income?', data= DATA, saturation=0.5)

# %%
DATA['If there was one thing you really wanted to own, what would that be?'].value_counts()
# Out:
# A Company    130
# A House       80
# Money         55
# Others        26
# A Car         11
# A Boat         1
# Name: If there was one thing you really wanted to own, what would that be?, dtype: int64

# %%
WhatYouWishToOwn = sbn.countplot(x="If there was one thing you really wanted to own, what would that be?", data= DATA, saturation=1.2, hue='If there was one thing you really wanted to own, what would that be?')

# %%
DATA['How much do you think you earn from all other sources of income in a month'].value_counts()
# Out:
# 0.000000e+00    67
# 1.000000e+04    37
# 2.000000e+04    31
# 3.000000e+04    22
# 1.000000e+05    22
# 5.000000e+03    19
# 5.000000e+04    19
# 1.500000e+04    11
# 1.500000e+05     6
# 3.000000e+05     5
# 5.000000e+05     4
# 3.000000e+03     4
# 2.000000e+03     3
# 1.000000e+03     3
# 1.000000e+01     3
# 7.000000e+04     3
# 4.000000e+04     3
# 2.500000e+04     2
# 8.000000e+04     2
# 4.000000e+01     2
# 5.000000e+01     2
# 3.500000e+05     2
# 2.000000e+05     2
# 1.200000e+05     2
# 1.000000e+10     2
# 1.500000e+03     2
# 2.500000e+05     2
# 5.500000e+05     1
# 8.000000e+03     1
# 1.600000e+05     1
# 4.000000e+05     1
# 2.500000e+03     1
# 5.500000e+04     1
# 1.580000e+05     1
# 1.400000e+05     1
# 7.000000e+01     1
# 3.000000e+01     1
# 1.800000e+05     1
# 8.100000e+01     1
# 2.000000e+01     1
# 9.000000e+04     1
# 2.230000e+05     1
# 6.500000e+05     1
# 2.300000e+05     1
# 1.286500e+05     1
# 7.000000e+05     1
# 1.800000e+04     1
# ...

# %%
OtherEarnings= sbn.countplot(y='How much do you think you earn from all other sources of income in a month', data=DATA)

# %%
DATA['Are you Happy with your job?'].value_counts()
# Out:
# Yes    176
# No     127
# Name: Are you Happy with your job?, dtype: int64

# %%
jobsatisfaction= sbn.countplot(x="Are you Happy with your job?", data= DATA, saturation=0.85, hue='Are you Happy with your job?')

# %%
DATA['What is your steady/constant income range in a month?'].value_counts()
# Out:
# 21,000 – 50,000      82
# 110,000 – 200,000    37
# 81,000 – 100,000     35
# 51,000 – 80,000      33
# Below 5000           29
# 11,000 – 20,000      29
# 201,000 – 300,000    23
# 5000 – 10,000        18
# 301,000 – 500,000     9
# 500,000 – above       8
# Name: What is your steady/constant income range in a month?, dtype: int64

# %%
income= sbn.countplot(y='What is your steady/constant income range in a month?', data= DATA)

# %%
DATA['Do you think Nigeria can get better?'].value_counts()
# Out:
# Yes    224
# No      79
# Name: Do you think Nigeria can get better?, dtype: int64

# %%
loveHate= sbn.countplot(x='Do you think Nigeria can get better?', data= DATA, saturation=1, hue='Do you think Nigeria can get better?')

# %%
DATA['In a short sentence, describe your government'].value_counts()
# Out:
# Selfish                                                                             9
# Corrupt                                                                             8
# Bad                                                                                 5
# Terrible                                                                            4
# Useless                                                                             3
#                                                                                    ..
# Inept and tyrannical                                                                1
# Inhumane, selfish,                                                                  1
# They need to be taught on how to lead and not to rule                               1
# They are working on irrelevant things and abandon the necessary responsibilities    1
# Unchanging                                                                          1
# ...

# %%
governance= sbn.countplot(y='In a short sentence, describe your government', data= DATA, hue='In a short sentence, describe your government')

# %% [markdown]
# **WHAT IS THE RELATIONSHIP BETWEEN JOB SATISFACTION, INCOME SATISFACTION AND OCCUPATION?**

# %% [markdown]
# #**Insight**
# out of 303 entries, 27 of the respondents are financial service providers and 17 out of this 27 people are satisfied with their jobs. Sadly, only 5 out of the 27 people thinks the money is enough for their family sustenance.
#
# > Sadly, out of 31 persons who identified their occupation as Engineering, only 15 are satisfied with their jobs. Only 4 out 0f this number are satisfied with their income.
#
# > 28 out of the occupation entries  are Entrepreneurs, 21 of them are satisfied with their jobs but none of them is satisfied with their income.
#
# > Out of 16 entries as Business personels, 11 of them are satisfied with their job and only one person is satified with the income(i.e it is sufficient to take care of the family.)
#
# > 23 entries identified the occupation as student and working.15 of them are satisfied with their jobs, only one is satisfied with their income.

# %%
fix = DATA.filter(["Occupation","Are you Happy with your job?","Do you think it is enough for you and your family?"])

# %%
FIN = fix[(fix["Occupation"] == "Financial Services") & (fix["Are you Happy with your job?"])]

# %%
FIN
# Out:
#              Occupation  ... Do you think it is enough for you and your family?
# 2    Financial Services  ...                                                 No
# 14   Financial Services  ...                                                 No
# 19   Financial Services  ...                                                 No
# 20   Financial Services  ...                                                Yes
# 21   Financial Services  ...                                                 No
# 59   Financial Services  ...                                                 No
# 60   Financial Services  ...                                                Yes
# 61   Financial Services  ...                                                Yes
# 75   Financial Services  ...                                                 No
# 77   Financial Services  ...                                                 No
# 87   Financial Services  ...                                                 No
# ...

# %%
ENG = fix[(fix["Occupation"] == "Engineering") & (fix["Are you Happy with your job?"])]

# %%
ENG
# Out:
#       Occupation  ... Do you think it is enough for you and your family?
# 4    Engineering  ...                                                Yes
# 11   Engineering  ...                                                 No
# 15   Engineering  ...                                                 No
# 18   Engineering  ...                                                 No
# 31   Engineering  ...                                                 No
# 39   Engineering  ...                                                 No
# 47   Engineering  ...                                                 No
# 48   Engineering  ...                                                 No
# 49   Engineering  ...                                                 No
# 50   Engineering  ...                                                 No
# 51   Engineering  ...                                                 No
# 57   Engineering  ...                                                 No
# ...

# %%
STD = fix[(fix["Occupation"] == "Student") & (fix["Are you Happy with your job?"])]

# %%
STD
# Out:
#     Occupation  ... Do you think it is enough for you and your family?
# 7      Student  ...                                                 No
# 13     Student  ...                                                 No
# 24     Student  ...                                                 No
# 25     Student  ...                                                 No
# 26     Student  ...                                                 No
# 27     Student  ...                                                 No
# 28     Student  ...                                                 No
# 29     Student  ...                                                 No
# 32     Student  ...                                                Yes
# 33     Student  ...                                                 No
# 34     Student  ...                                                 No
# 52     Student  ...                                                 No
# ...

# %%
SE = fix[(fix["Occupation"] == "Software Engineering/Computer Design") & (fix["Are you Happy with your job?"])]

# %%
SE
# Out:
# Empty DataFrame
# Columns: [Occupation, Are you Happy with your job?, Do you think it is enough for you and your family?]
# Index: []

# %%
ENT = fix[(fix["Occupation"] == "Entrepreneur") & (fix["Are you Happy with your job?"])]

# %%
ENT
# Out:
#        Occupation  ... Do you think it is enough for you and your family?
# 8    Entrepreneur  ...                                                 No
# 9    Entrepreneur  ...                                                 No
# 17   Entrepreneur  ...                                                 No
# 22   Entrepreneur  ...                                                 No
# 35   Entrepreneur  ...                                                 No
# 36   Entrepreneur  ...                                                 No
# 45   Entrepreneur  ...                                                 No
# 53   Entrepreneur  ...                                                 No
# 58   Entrepreneur  ...                                                 No
# 62   Entrepreneur  ...                                                 No
# 65   Entrepreneur  ...                                                 No
# 72   Entrepreneur  ...                                                 No
# ...

# %%
STDW = fix[(fix["Occupation"] == "Student and Working") & (fix["Are you Happy with your job?"])]

# %%
STDW
# Out:
#               Occupation  ... Do you think it is enough for you and your family?
# 113  Student and Working  ...                                                 No
# 124  Student and Working  ...                                                 No
# 134  Student and Working  ...                                                Yes
# 144  Student and Working  ...                                                 No
# 146  Student and Working  ...                                                 No
# 151  Student and Working  ...                                                 No
# 157  Student and Working  ...                                                 No
# 159  Student and Working  ...                                                 No
# 160  Student and Working  ...                                                 No
# 164  Student and Working  ...                                                 No
# 167  Student and Working  ...                                                 No
# ...

# %%
len(STDW)
# Out:
# 23

# %%
BUS = fix[(fix["Occupation"] == "Business") & (fix["Are you Happy with your job?"])]

# %%
BUS
# Out:
#     Occupation  ... Do you think it is enough for you and your family?
# 3     Business  ...                                                 No
# 43    Business  ...                                                 No
# 81    Business  ...                                                 No
# 97    Business  ...                                                 No
# 116   Business  ...                                                 No
# 135   Business  ...                                                 No
# 137   Business  ...                                                 No
# 179   Business  ...                                                 No
# 180   Business  ...                                                 No
# 200   Business  ...                                                 No
# 217   Business  ...                                                 No
# 224   Business  ...                                                 No
# ...

# %%
len(BUS)
# Out:
# 16

# %%
NONE = fix[(fix["Occupation"] == "No Job") & (fix["Are you Happy with your job?"])]

# %%
NONE
# Out:
#     Occupation  ... Do you think it is enough for you and your family?
# 1       No Job  ...                                                 No
# 12      No Job  ...                                                 No
# 37      No Job  ...                                                 No
# 41      No Job  ...                                                 No
# 44      No Job  ...                                                 No
# 55      No Job  ...                                                 No
# 69      No Job  ...                                                 No
# 70      No Job  ...                                                 No
# 73      No Job  ...                                                 No
# 100     No Job  ...                                                Yes
# 112     No Job  ...                                                 No
# 125     No Job  ...                                                 No
# ...
